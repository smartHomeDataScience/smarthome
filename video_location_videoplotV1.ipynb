# %%
import numpy as np
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 30,5
sns.set_style('whitegrid')

# %%
# from pymongo import MongoClient

# db = MongoClient('mongodb://localhost/SmartHome', 27017).SmartHome

# %%
# table = db.video_living_room.find({})

# %%
PATH ='C:/Users/ralkh/Desktop/smarthome-master/'

df_location = pd.read_csv('C:/Users/ralkh/Desktop/smarthome-master/data/train/00001/location_0_timeseries.csv')
df_location.head()
# Out:
#    Unnamed: 0   time location
# 0           0  47.33   living
# 1           1  47.36   living
# 2           2  47.39   living
# 3           3  47.42   living
# 4           4  47.45   living

# %%
df_location['time'].count()
# Out:
# 1758

# %%
df_video = pd.read_csv('C:/Users/ralkh/Desktop/smarthome-master/data/train/00001/VideoLocation_timeseries.csv')
df_video.head()
# Out:
#    Unnamed: 0       t VideoLocation
# 0           0  13.014       hallway
# 1           1  13.045       hallway
# 2           2  13.076       hallway
# 3           3  13.107       hallway
# 4           4  13.139       hallway

# %%
df_location.axes
# Out:
# [RangeIndex(start=0, stop=1758, step=1),
#  Index(['Unnamed: 0', 'time', 'location'], dtype='object')]

# %%
df_video
# Out:
#        Unnamed: 0         t VideoLocation
# 0               0    13.014       hallway
# 1               1    13.045       hallway
# 2               2    13.076       hallway
# 3               3    13.107       hallway
# 4               4    13.139       hallway
# 5               5    13.170       hallway
# 6               6    13.201       hallway
# 7               7    13.232       hallway
# 8               8    13.264       hallway
# 9               9    13.295       hallway
# 10             10    13.342       hallway
# 11             11    13.373       hallway
# 12             12    13.389       hallway
# 13             13    13.435       hallway
# 14             14    13.467       hallway
# 15             15    13.498       hallway
# 16             16    13.545       hallway
# 17             17    13.576       hallway
# 18             18    13.607       hallway
# 19             19    13.639       hallway
# 20             20    13.670       hallway
# ...

# %%
sns.set(style="whitegrid", color_codes=True)
sns.violinplot(x="VideoLocation", y="t", data=df_video, inner=None)
sns.swarmplot(x="location", y="time", data=df_location, color="b", alpha=.5);
