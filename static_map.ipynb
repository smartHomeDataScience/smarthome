# %%
import matplotlib.pyplot as plt
import numpy as np

##########################################
####### FIRST FLOOR
##########################################

x = [2.85 ,4.65 ,4.65 , 0 , 0, 2.85,2.85] ;
y = [0 ,0   , 10.45, 10.45, 3.2,3.2,0];

# Lines on top of scatter
plt.figure(figsize=(10,35))
plt.subplot(311)
plt.plot(x, y, 'r', lw=3)
#BATHROOM
Bath_x = [2.85 , 4.65 , 4.65 , 2.85 , 2.85]; 
Bath_y = [ 0   , 0    , 3.2 , 3.2 , 0 ];

plt.plot(Bath_x, Bath_y, 'b', lw=1)
plt.text(3.15, 1.575, 'BATH / SHOWER', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#BEDROOM 1
Bedroom1_x = [ 0,3.4,3.4,0,0]; 
Bedroom1_y = [ 3.2,3.2,6.8,6.8,3.2];

plt.plot(Bedroom1_x, Bedroom1_y, 'b', lw=1)
plt.text(1.425, 5, 'BEDROOM 1', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#BEDROOM 2
Bedroom2_x = [ 0  , 3.8, 3.8  , 0   , 0]; 
Bedroom2_y = [ 6.8, 6.8, 10.45, 10.45 , 6.8];

plt.plot(Bedroom2_x, Bedroom2_y, 'b', lw=1)
plt.text(1.425, 8.625, 'BEDROOM 2', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})


# plt.plot(Bedroom_x, Bedroom_y, 'b', lw=1)
# plt.text(3.15, 1.575, 'BEDROOM 1', style='italic',
#         bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#LANDING
Landing_x = [ 3.4 ,4.65 , 4.65 , 3.8 , 3.8, 3.4 ,3.4]; 
Landing_y = [ 3.2 ,3.2  , 8.2  , 8.2 , 6.8 , 6.8 , 3.2];

plt.plot(Landing_x, Landing_y, 'b', lw=1)
plt.text(3.925, 5.7, 'LANDING', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#WC
Wc_x = [ 3.8, 4.65, 4.65, 3.8   , 3.8]; 
Wc_y = [ 8.2, 8.2, 10.45, 10.45 , 8.2];

plt.plot(Wc_x, Wc_y, 'b', lw=1)
plt.text( 4.225, 9.325 , 'WC', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

plt.scatter(x, y, s=120)
plt.title('FIRST FLOOR')

# # Scatter plot on top of lines
# plt.subplot(212)
# plt.plot(x, y, 'r', zorder=1, lw=3)
# plt.scatter(x, y, s=120, zorder=2)
# plt.title('Dots on top of lines')

plt.show();
# Out:
# /Users/RababAhmad/anaconda/envs/ffmpeg/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt
import numpy as np

# x = [1.45, 4.65 ,4.65 , 0 , 0 , 1.45 ,1.45 ] * 100 ;
# y = [0 , 0 , 8.75 ,8.75 ,3.15 ,3.15 , 0] * 100;

x = [ 1.65 ,4.65,4.65 ,0,0,1.65,1.65];
y = [0,0,10.45,10.45,3.15,3.15,0]

# Lines on top of scatter
plt.figure(figsize=(10,35))
plt.subplot(211)
plt.plot(x, y, 'r', lw=3)

##########################################
####### Ground Floor
##########################################

#KITCHEN G.03
kitchen_x = [1.65 , 4.65 , 4.65 , 1.65 , 1.65]; 
kitchen_y = [ 0   , 0    , 3.15 , 3.15 , 0 ];

plt.plot(kitchen_x, kitchen_y, 'b', lw=1)
plt.text(3.15, 1.575, 'KITCHEN G.03', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#BedRoom 1 G.02
BedRoom_x = [0,2.9,2.9,0,0];
BedRoom_y = [3.15,3.15,6.75,6.75,3.15];

plt.plot(BedRoom_x, BedRoom_y, 'b', lw=1)
plt.text(1.45, 4.95, 'BedRoom 1 G.02', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#HALL B.G.01
HALL_x = [4.41 , 4.65, 4.65, 4.41, 4.41];
HALL_y = [6.75, 6.75, 10.45, 10.45, 6.75];

plt.plot(HALL_x, HALL_y, 'b', lw=1)
plt.text(4.53, 8.6, 'HALL G.01', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

#LOUNGE G.01
Lounch_x = [0,4.41,4.41,0,0];
Lounch_y = [6.75,6.75,10.45,10.45,6.75];

plt.plot(Lounch_x, Lounch_y, 'b', lw=1)
plt.text(2.205, 8.6, 'LOUNGE G.01', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})


plt.scatter(x, y, s=120)
plt.title('GROUND FLOOR')

plt.show();
